# %% [markdown]
# # 7.3 Extending Data Type

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 2, 3, None])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s = pd.Series([1, 2, 3, None], dtype=pd.Int64Dtype())

# %%
s
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# dtype: Int64

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
s.dtype
# Out:
# Int64Dtype()

# %%
s[3]

# %%
s[3] is pd.NA
# Out:
# True

# %%
s = pd.Series([1, 2, 3, None], dtype='Int64')

# %%
s = pd.Series(['one', 'two', 'None', 'three'], dtype=pd.StringDtype())

# %%
s
# Out:
# 0      one
# 1      two
# 2     None
# 3    three
# dtype: string
